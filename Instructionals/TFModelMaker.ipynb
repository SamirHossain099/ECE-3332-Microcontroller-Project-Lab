# %%
#select venv interpreter
import numpy as np
import os
from tflite_model_maker.config import ExportFormat, QuantizationConfig
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector
from tflite_support import metadata

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
# Out:
# c:\Users\Nicop\Desktop\VerilogLabs\ECE-3332-Microcontroller-Project-Lab\.venv\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Nicop\Desktop\VerilogLabs\ECE-3332-Microcontroller-Project-Lab\.venv\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# ...

# %%
#load data
train_data = object_detector.DataLoader.from_pascal_voc(
    '../RaccoonIMGS/train',
    '../RaccoonIMGS/train',
    ['raccoon']
)
val_data = object_detector.DataLoader.from_pascal_voc(
    '../RaccoonIMGS/validate',
    '../RaccoonIMGS/validate',
    ['raccoon']
)
print(f"Size of train_data: {len(train_data)}")
print(f"Size of val_data: {len(val_data)}")
# Out:
# Size of train_data: 71
# Size of val_data: 29

# %%
spec = model_spec.get('efficientdet_lite0')
model = object_detector.create(train_data, model_spec=spec, batch_size=4, train_whole_model=True, epochs=80, validation_data=val_data)
# Out:
# Epoch 1/80
# 17/17 [==============================] - 48s 2s/step - det_loss: 1.7216 - cls_loss: 1.1231 - box_loss: 0.0120 - reg_l2_loss: 0.0630 - loss: 1.7846 - learning_rate: 0.0065 - gradient_norm: 1.5878 - val_det_loss: 1.6254 - val_cls_loss: 1.0458 - val_box_loss: 0.0116 - val_reg_l2_loss: 0.0630 - val_loss: 1.6884
# Epoch 2/80
# 17/17 [==============================] - 25s 2s/step - det_loss: 1.5078 - cls_loss: 0.9852 - box_loss: 0.0105 - reg_l2_loss: 0.0630 - loss: 1.5708 - learning_rate: 0.0050 - gradient_norm: 2.4173 - val_det_loss: 1.2603 - val_cls_loss: 0.7663 - val_box_loss: 0.0099 - val_reg_l2_loss: 0.0630 - val_loss: 1.3232
# Epoch 3/80
# 17/17 [==============================] - 24s 1s/step - det_loss: 1.1562 - cls_loss: 0.7164 - box_loss: 0.0088 - reg_l2_loss: 0.0630 - loss: 1.2192 - learning_rate: 0.0050 - gradient_norm: 3.9883 - val_det_loss: 1.2826 - val_cls_loss: 0.8812 - val_box_loss: 0.0080 - val_reg_l2_loss: 0.0630 - val_loss: 1.3456
# Epoch 4/80
# ...

# %%
model.evaluate(val_data)
# Out:
# 1/1 [==============================] - 5s 5s/step
# {'AP': 0.69884086,
#  'AP50': 0.97350454,
#  'AP75': 0.8295609,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.70363027,
#  'ARmax1': 0.7266667,
#  'ARmax10': 0.79333335,
#  'ARmax100': 0.79333335,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.79333335,
#  'AP_/raccoon': 0.69884086}
